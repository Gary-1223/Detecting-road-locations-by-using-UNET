# %%
pip install opencv-python numpy
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)

# %%
import cv2
import numpy as np
import os

def convert_to_binary_road(input_path, output_path):
    # 讀取圖片
    img = cv2.imread(input_path)

    # 如果圖片讀取失敗，返回錯誤信息
    if img is None:
        return f"無法讀取圖片: {input_path}"

    # 獲取原始圖片尺寸
    height, width = img.shape[:2]

    # 創建空白圖片(全白)
    binary_img = np.ones((height, width), dtype=np.uint8) * 255

    # 在原始圖片中找到紫色道路的像素
    road_mask = cv2.inRange(img,
                          np.array([100, 0, 100]),
                          np.array([255, 100, 255]))

    # 將道路區域設為黑色(0)
    binary_img[road_mask > 0] = 0

    # 儲存結果
    cv2.imwrite(output_path, binary_img)

    return f"成功處理: {input_path}"

def process_directory(input_dir, output_dir):
    # 確保輸出目錄存在
    os.makedirs(output_dir, exist_ok=True)

    # 支援的圖片格式
    valid_extensions = ('.png', '.jpg', '.jpeg', '.bmp')

    # 計數器
    processed = 0
    failed = 0

    # 處理所有圖片
    for filename in os.listdir(input_dir):
        # 檢查文件副檔名
        if filename.lower().endswith(valid_extensions):
            input_path = os.path.join(input_dir, filename)

            # 生成新的檔案名稱：移除原有副檔名，加上 _labeled.png
            base_name = os.path.splitext(filename)[0]
            output_filename = f"{base_name}_labeled.png"
            output_path = os.path.join(output_dir, output_filename)

            try:
                result = convert_to_binary_road(input_path, output_path)
                print(result)
                processed += 1
            except Exception as e:
                print(f"處理 {filename} 時發生錯誤: {str(e)}")
                failed += 1

    return f"處理完成！成功: {processed} 個文件，失敗: {failed} 個文件"

# 使用範例
input_directory = "/content/1"  # 請替換成你的輸入資料夾路徑
output_directory = "/content/output1"  # 請替換成你想要的輸出資料夾路徑

result = process_directory(input_directory, output_directory)
print(result)
# Out:
# 成功處理: /content/1/0016E5_01380_L.png
# 成功處理: /content/1/0016E5_08129_L.png
# 成功處理: /content/1/0016E5_06480_L.png
# 成功處理: /content/1/Seq05VD_f01350_L.png
# 成功處理: /content/1/0016E5_06570_L.png
# 成功處理: /content/1/Seq05VD_f02400_L.png
# 成功處理: /content/1/0006R0_f02340_L.png
# 成功處理: /content/1/Seq05VD_f00840_L.png
# 成功處理: /content/1/Seq05VD_f00360_L.png
# 成功處理: /content/1/Seq05VD_f04500_L.png
# 成功處理: /content/1/0016E5_00840_L.png
# 成功處理: /content/1/Seq05VD_f03840_L.png
# 成功處理: /content/1/Seq05VD_f02040_L.png
# 成功處理: /content/1/0006R0_f02670_L.png
# 成功處理: /content/1/0016E5_08157_L.png
# 成功處理: /content/1/Seq05VD_f02100_L.png
# 成功處理: /content/1/Seq05VD_f00810_L.png
# 成功處理: /content/1/Seq05VD_f04350_L.png
# 成功處理: /content/1/0016E5_04830_L.png
# 成功處理: /content/1/0016E5_08460_L.png
# 成功處理: /content/1/0001TP_006990_L.png
# 成功處理: /content/1/0006R0_f02070_L.png
# 成功處理: /content/1/0016E5_08550_L.png
# 成功處理: /content/1/0001TP_008490_L.png
# 成功處理: /content/1/0001TP_008010_L.png
# 成功處理: /content/1/0016E5_08141_L.png
# 成功處理: /content/1/Seq05VD_f04530_L.png
# 成功處理: /content/1/0016E5_08400_L.png
# 成功處理: /content/1/Seq05VD_f04560_L.png
# 成功處理: /content/1/0016E5_08027_L.png
# 成功處理: /content/1/Seq05VD_f00600_L.png
# 成功處理: /content/1/Seq05VD_f00300_L.png
# 成功處理: /content/1/0001TP_007890_L.png
# 成功處理: /content/1/Seq05VD_f03120_L.png
# 成功處理: /content/1/0016E5_01110_L.png
# 成功處理: /content/1/0001TP_010020_L.png
# 成功處理: /content/1/0016E5_02010_L.png
# 成功處理: /content/1/0001TP_007710_L.png
# 成功處理: /content/1/0001TP_008400_L.png
# 成功處理: /content/1/0016E5_08139_L.png
# 成功處理: /content/1/0001TP_009420_L.png
# 成功處理: /content/1/0016E5_00600_L.png
# 成功處理: /content/1/0016E5_08053_L.png
# 成功處理: /content/1/0016E5_08051_L.png
# 成功處理: /content/1/0016E5_08123_L.png
# 成功處理: /content/1/Seq05VD_f02760_L.png
# 成功處理: /content/1/0016E5_08017_L.png
# 成功處理: /content/1/0016E5_08029_L.png
# 成功處理: /content/1/0016E5_08005_L.png
# 成功處理: /content/1/0016E5_01230_L.png
# 成功處理: /content/1/0016E5_07997_L.png
# 成功處理: /content/1/Seq05VD_f03990_L.png
# 成功處理: /content/1/0006R0_f03900_L.png
# 成功處理: /content/1/Seq05VD_f01860_L.png
# 成功處理: /content/1/0006R0_f01350_L.png
# 成功處理: /content/1/0001TP_007680_L.png
# 成功處理: /content/1/0016E5_05760_L.png
# 成功處理: /content/1/Seq05VD_f04290_L.png
# 成功處理: /content/1/0016E5_04380_L.png
# 成功處理: /content/1/0016E5_07620_L.png
# 成功處理: /content/1/0016E5_07290_L.png
# 成功處理: /content/1/0016E5_08021_L.png
# 成功處理: /content/1/0016E5_04500_L.png
# 成功處理: /content/1/0016E5_00870_L.png
# 成功處理: /content/1/0016E5_01500_L.png
# 成功處理: /content/1/Seq05VD_f02880_L.png
# 成功處理: /content/1/0016E5_08113_L.png
# 成功處理: /content/1/Seq05VD_f01200_L.png
# 成功處理: /content/1/0001TP_008610_L.png
# 成功處理: /content/1/0016E5_08159_L.png
# 成功處理: /content/1/Seq05VD_f01950_L.png
# 成功處理: /content/1/Seq05VD_f04920_L.png
# 成功處理: /content/1/0001TP_009180_L.png
# 成功處理: /content/1/Seq05VD_f03180_L.png
# 成功處理: /content/1/Seq05VD_f01140_L.png
# 成功處理: /content/1/0006R0_f03630_L.png
# 成功處理: /content/1/0006R0_f01710_L.png
# 成功處理: /content/1/Seq05VD_f03870_L.png
# 成功處理: /content/1/0006R0_f01410_L.png
# 成功處理: /content/1/0016E5_00480_L.png
# 成功處理: /content/1/Seq05VD_f00570_L.png
# 成功處理: /content/1/0016E5_07977_L.png
# 成功處理: /content/1/0001TP_007860_L.png
# 成功處理: /content/1/0016E5_08310_L.png
# 成功處理: /content/1/Seq05VD_f05010_L.png
# 成功處理: /content/1/0016E5_01050_L.png
# 成功處理: /content/1/0016E5_07991_L.png
# 成功處理: /content/1/Seq05VD_f03510_L.png
# 成功處理: /content/1/0016E5_06360_L.png
# 成功處理: /content/1/0006R0_f02640_L.png
# 成功處理: /content/1/0016E5_00450_L.png
# 成功處理: /content/1/0016E5_00420_L.png
# 成功處理: /content/1/0016E5_07987_L.png
# 成功處理: /content/1/0016E5_05940_L.png
# 成功處理: /content/1/0001TP_008190_L.png
# 成功處理: /content/1/0016E5_05310_L.png
# 成功處理: /content/1/0016E5_08115_L.png
# 成功處理: /content/1/0016E5_08063_L.png
# 成功處理: /content/1/0016E5_02310_L.png
# 成功處理: /content/1/0006R0_f01320_L.png
# 成功處理: /content/1/0001TP_009300_L.png
# 成功處理: /content/1/0001TP_008700_L.png
# 成功處理: /content/1/Seq05VD_f00240_L.png
# 成功處理: /content/1/0016E5_01320_L.png
# 成功處理: /content/1/0006R0_f02550_L.png
# 成功處理: /content/1/Seq05VD_f03720_L.png
# 成功處理: /content/1/0016E5_06030_L.png
# 成功處理: /content/1/0006R0_f01950_L.png
# 成功處理: /content/1/Seq05VD_f01620_L.png
# 成功處理: /content/1/0016E5_08131_L.png
# 成功處理: /content/1/0006R0_f03210_L.png
# 成功處理: /content/1/0006R0_f01830_L.png
# 成功處理: /content/1/0016E5_08580_L.png
# 成功處理: /content/1/0016E5_06810_L.png
# 成功處理: /content/1/0001TP_008730_L.png
# 成功處理: /content/1/0001TP_009060_L.png
# 成功處理: /content/1/0016E5_07800_L.png
# 成功處理: /content/1/0016E5_07999_L.png
# 成功處理: /content/1/0016E5_06210_L.png
# 成功處理: /content/1/0001TP_007800_L.png
# 成功處理: /content/1/0016E5_07680_L.png
# 成功處理: /content/1/0016E5_04950_L.png
# 成功處理: /content/1/0016E5_00990_L.png
# 成功處理: /content/1/0016E5_05130_L.png
# 成功處理: /content/1/0001TP_007170_L.png
# 成功處理: /content/1/0001TP_010230_L.png
# 成功處理: /content/1/Seq05VD_f03570_L.png
# 成功處理: /content/1/Seq05VD_f04050_L.png
# 成功處理: /content/1/0016E5_08073_L.png
# 成功處理: /content/1/0016E5_04680_L.png
# 成功處理: /content/1/0006R0_f01140_L.png
# 成功處理: /content/1/0001TP_009510_L.png
# 成功處理: /content/1/0006R0_f03300_L.png
# 成功處理: /content/1/Seq05VD_f00750_L.png
# 成功處理: /content/1/Seq05VD_f02310_L.png
# 成功處理: /content/1/0016E5_08153_L.png
# 成功處理: /content/1/0006R0_f03660_L.png
# 成功處理: /content/1/Seq05VD_f01590_L.png
# 成功處理: /content/1/0016E5_05850_L.png
# 成功處理: /content/1/0006R0_f01050_L.png
# 成功處理: /content/1/0016E5_07971_L.png
# 成功處理: /content/1/0016E5_07230_L.png
# 成功處理: /content/1/Seq05VD_f03480_L.png
# 成功處理: /content/1/0016E5_06600_L.png
# 成功處理: /content/1/0001TP_007440_L.png
# 成功處理: /content/1/0016E5_08117_L.png
# 成功處理: /content/1/0001TP_009120_L.png
# 成功處理: /content/1/0006R0_f01860_L.png
# 成功處理: /content/1/0016E5_05820_L.png
# 成功處理: /content/1/0001TP_007950_L.png
# 成功處理: /content/1/0016E5_08081_L.png
# 成功處理: /content/1/0016E5_08101_L.png
# 成功處理: /content/1/0001TP_007980_L.png
# 成功處理: /content/1/0016E5_06510_L.png
# 成功處理: /content/1/0006R0_f03780_L.png
# 成功處理: /content/1/0016E5_05400_L.png
# 成功處理: /content/1/0006R0_f03870_L.png
# 成功處理: /content/1/Seq05VD_f01110_L.png
# 成功處理: /content/1/0001TP_008340_L.png
# 成功處理: /content/1/0001TP_009210_L.png
# 成功處理: /content/1/Seq05VD_f00930_L.png
# 成功處理: /content/1/0001TP_008100_L.png
# 成功處理: /content/1/0016E5_07967_L.png
# 成功處理: /content/1/Seq05VD_f00630_L.png
# 成功處理: /content/1/0016E5_01470_L.png
# 成功處理: /content/1/Seq05VD_f04110_L.png
# 成功處理: /content/1/0016E5_06690_L.png
# 成功處理: /content/1/0001TP_007380_L.png
# 成功處理: /content/1/0016E5_08059_L.png
# 成功處理: /content/1/0001TP_009600_L.png
# 成功處理: /content/1/0006R0_f03840_L.png
# 成功處理: /content/1/0006R0_f03180_L.png
# 成功處理: /content/1/0016E5_01980_L.png
# 成功處理: /content/1/0016E5_05430_L.png
# 成功處理: /content/1/0016E5_07530_L.png
# 成功處理: /content/1/0001TP_008520_L.png
# 成功處理: /content/1/Seq05VD_f03240_L.png
# 成功處理: /content/1/0006R0_f02190_L.png
# 成功處理: /content/1/0001TP_010110_L.png
# 成功處理: /content/1/0016E5_08039_L.png
# 成功處理: /content/1/0006R0_f01500_L.png
# 成功處理: /content/1/Seq05VD_f00990_L.png
# 成功處理: /content/1/0001TP_006750_L.png
# 成功處理: /content/1/0001TP_008640_L.png
# 成功處理: /content/1/0016E5_07989_L.png
# 成功處理: /content/1/0016E5_07500_L.png
# 成功處理: /content/1/0016E5_08041_L.png
# 成功處理: /content/1/0016E5_02130_L.png
# 成功處理: /content/1/Seq05VD_f01680_L.png
# 成功處理: /content/1/0016E5_08089_L.png
# 成功處理: /content/1/0001TP_009930_L.png
# 成功處理: /content/1/Seq05VD_f02190_L.png
# 成功處理: /content/1/Seq05VD_f00060_L.png
# 成功處理: /content/1/0006R0_f03930_L.png
# 成功處理: /content/1/0006R0_f03030_L.png
# 成功處理: /content/1/0016E5_06720_L.png
# 成功處理: /content/1/0016E5_08430_L.png
# 成功處理: /content/1/Seq05VD_f03750_L.png
# 成功處理: /content/1/0006R0_f01470_L.png
# 成功處理: /content/1/0016E5_07380_L.png
# 成功處理: /content/1/0016E5_00780_L.png
# 成功處理: /content/1/Seq05VD_f04470_L.png
# 成功處理: /content/1/0016E5_01920_L.png
# 成功處理: /content/1/0016E5_08135_L.png
# 成功處理: /content/1/0016E5_05790_L.png
# 成功處理: /content/1/Seq05VD_f04380_L.png
# 成功處理: /content/1/0016E5_08045_L.png
# 成功處理: /content/1/Seq05VD_f03300_L.png
# 成功處理: /content/1/Seq05VD_f04260_L.png
# 成功處理: /content/1/0016E5_07710_L.png
# 成功處理: /content/1/0016E5_08009_L.png
# 成功處理: /content/1/0016E5_08250_L.png
# 成功處理: /content/1/Seq05VD_f01410_L.png
# 成功處理: /content/1/0001TP_008250_L.png
# 成功處理: /content/1/0006R0_f02460_L.png
# 成功處理: /content/1/0016E5_08280_L.png
# 成功處理: /content/1/0016E5_08003_L.png
# 成功處理: /content/1/0016E5_08071_L.png
# 成功處理: /content/1/0016E5_00810_L.png
# 成功處理: /content/1/0016E5_06060_L.png
# 成功處理: /content/1/0016E5_06450_L.png
# 成功處理: /content/1/0016E5_08220_L.png
# 成功處理: /content/1/0016E5_08121_L.png
# 成功處理: /content/1/0016E5_02220_L.png
# 成功處理: /content/1/0016E5_08107_L.png
# 成功處理: /content/1/0001TP_010260_L.png
# 成功處理: /content/1/0016E5_07920_L.png
# 成功處理: /content/1/0016E5_07470_L.png
# 成功處理: /content/1/0001TP_009450_L.png
# 成功處理: /content/1/0016E5_08055_L.png
# 成功處理: /content/1/Seq05VD_f01470_L.png
# 成功處理: /content/1/0006R0_f01200_L.png
# 成功處理: /content/1/0016E5_05490_L.png
# 成功處理: /content/1/Seq05VD_f01980_L.png
# 成功處理: /content/1/0016E5_04620_L.png
# 成功處理: /content/1/0006R0_f01230_L.png
# 成功處理: /content/1/Seq05VD_f01230_L.png
# 成功處理: /content/1/Seq05VD_f01890_L.png
# 成功處理: /content/1/Seq05VD_f02610_L.png
# 成功處理: /content/1/Seq05VD_f02550_L.png
# 成功處理: /content/1/0001TP_010290_L.png
# 成功處理: /content/1/0016E5_07890_L.png
# 成功處理: /content/1/0016E5_08095_L.png
# 成功處理: /content/1/0001TP_009390_L.png
# 成功處理: /content/1/0016E5_08490_L.png
# 成功處理: /content/1/0006R0_f02730_L.png
# 成功處理: /content/1/0016E5_08011_L.png
# 成功處理: /content/1/0006R0_f02790_L.png
# 成功處理: /content/1/0006R0_f03060_L.png
# 成功處理: /content/1/0016E5_02190_L.png
# 成功處理: /content/1/0006R0_f03510_L.png
# 成功處理: /content/1/0006R0_f01980_L.png
# 成功處理: /content/1/0006R0_f03480_L.png
# 成功處理: /content/1/0001TP_008940_L.png
# 成功處理: /content/1/0016E5_08077_L.png
# 成功處理: /content/1/0016E5_01290_L.png
# 成功處理: /content/1/0016E5_07080_L.png
# 成功處理: /content/1/0016E5_08610_L.png
# 成功處理: /content/1/0016E5_05640_L.png
# 成功處理: /content/1/0016E5_05370_L.png
# 成功處理: /content/1/0016E5_07050_L.png
# 成功處理: /content/1/Seq05VD_f00870_L.png
# 成功處理: /content/1/0006R0_f02580_L.png
# 成功處理: /content/1/0006R0_f01290_L.png
# 成功處理: /content/1/0001TP_009690_L.png
# 成功處理: /content/1/0016E5_08007_L.png
# 成功處理: /content/1/0001TP_006690_L.png
# 成功處理: /content/1/0016E5_02040_L.png
# 成功處理: /content/1/0006R0_f01080_L.png
# 成功處理: /content/1/0001TP_010320_L.png
# 成功處理: /content/1/0016E5_08151_L.png
# 成功處理: /content/1/0016E5_02280_L.png
# 成功處理: /content/1/0006R0_f01260_L.png
# 成功處理: /content/1/0016E5_05460_L.png
# 成功處理: /content/1/Seq05VD_f03600_L.png
# 成功處理: /content/1/0001TP_006840_L.png
# 成功處理: /content/1/Seq05VD_f04170_L.png
# 成功處理: /content/1/0016E5_01950_L.png
# 成功處理: /content/1/0016E5_00390_L.png
# 成功處理: /content/1/0016E5_08105_L.png
# 成功處理: /content/1/0001TP_008910_L.png
# 成功處理: /content/1/0001TP_007320_L.png
# 成功處理: /content/1/0016E5_05910_L.png
# 成功處理: /content/1/0016E5_00720_L.png
# 成功處理: /content/1/0016E5_04560_L.png
# 成功處理: /content/1/0001TP_007110_L.png
# 成功處理: /content/1/0001TP_009090_L.png
# 成功處理: /content/1/0006R0_f02910_L.png
# 成功處理: /content/1/0016E5_08093_L.png
# 成功處理: /content/1/0016E5_06420_L.png
# 成功處理: /content/1/0006R0_f02760_L.png
# 成功處理: /content/1/0016E5_08111_L.png
# 成功處理: /content/1/0006R0_f02940_L.png
# 成功處理: /content/1/0016E5_05100_L.png
# 成功處理: /content/1/0001TP_007470_L.png
# 成功處理: /content/1/0016E5_05160_L.png
# 成功處理: /content/1/0001TP_008070_L.png
# 成功處理: /content/1/0016E5_08147_L.png
# 成功處理: /content/1/Seq05VD_f00450_L.png
# 成功處理: /content/1/0016E5_07963_L.png
# 成功處理: /content/1/0016E5_02400_L.png
# 成功處理: /content/1/Seq05VD_f03390_L.png
# 成功處理: /content/1/0016E5_01740_L.png
# 成功處理: /content/1/Seq05VD_f00420_L.png
# 成功處理: /content/1/0006R0_f02310_L.png
# 成功處理: /content/1/Seq05VD_f03690_L.png
# 成功處理: /content/1/Seq05VD_f03030_L.png
# 成功處理: /content/1/0016E5_08033_L.png
# 成功處理: /content/1/0016E5_08015_L.png
# 成功處理: /content/1/0016E5_07995_L.png
# 成功處理: /content/1/0016E5_00540_L.png
# 成功處理: /content/1/0016E5_08001_L.png
# 成功處理: /content/1/0016E5_01830_L.png
# 成功處理: /content/1/0001TP_007410_L.png
# 成功處理: /content/1/0016E5_08520_L.png
# 成功處理: /content/1/0016E5_06300_L.png
# 成功處理: /content/1/0006R0_f03270_L.png
# 成功處理: /content/1/Seq05VD_f00330_L.png
# 成功處理: /content/1/0016E5_06630_L.png
# 成功處理: /content/1/0016E5_06120_L.png
# 成功處理: /content/1/0016E5_07350_L.png
# 成功處理: /content/1/0016E5_07983_L.png
# 成功處理: /content/1/Seq05VD_f04950_L.png
# 成功處理: /content/1/0016E5_08025_L.png
# 成功處理: /content/1/0016E5_00960_L.png
# 成功處理: /content/1/0006R0_f02970_L.png
# 成功處理: /content/1/0006R0_f01170_L.png
# 成功處理: /content/1/0006R0_f02220_L.png
# 成功處理: /content/1/0016E5_01890_L.png
# 成功處理: /content/1/0006R0_f02850_L.png
# 成功處理: /content/1/0016E5_04530_L.png
# 成功處理: /content/1/0001TP_007650_L.png
# 成功處理: /content/1/0001TP_007770_L.png
# 成功處理: /content/1/0001TP_006780_L.png
# 成功處理: /content/1/0016E5_08043_L.png
# 成功處理: /content/1/0001TP_009570_L.png
# 成功處理: /content/1/Seq05VD_f00120_L.png
# 成功處理: /content/1/0016E5_02160_L.png
# 成功處理: /content/1/0016E5_01650_L.png
# 成功處理: /content/1/0001TP_007080_L.png
# 成功處理: /content/1/0006R0_f03420_L.png
# 成功處理: /content/1/0016E5_05730_L.png
# 成功處理: /content/1/0016E5_04860_L.png
# 成功處理: /content/1/Seq05VD_f03960_L.png
# 成功處理: /content/1/Seq05VD_f03780_L.png
# 成功處理: /content/1/0001TP_008970_L.png
# 成功處理: /content/1/0001TP_010050_L.png
# 成功處理: /content/1/Seq05VD_f03810_L.png
# 成功處理: /content/1/0001TP_009630_L.png
# 成功處理: /content/1/Seq05VD_f00210_L.png
# 成功處理: /content/1/Seq05VD_f03540_L.png
# 成功處理: /content/1/0016E5_06840_L.png
# 成功處理: /content/1/0016E5_06930_L.png
# 成功處理: /content/1/0001TP_007830_L.png
# 成功處理: /content/1/Seq05VD_f04080_L.png
# 成功處理: /content/1/0016E5_06780_L.png
# 成功處理: /content/1/0016E5_06330_L.png
# 成功處理: /content/1/0016E5_08133_L.png
# 成功處理: /content/1/Seq05VD_f00030_L.png
# 成功處理: /content/1/0016E5_00901_L.png
# 成功處理: /content/1/0001TP_007350_L.png
# 成功處理: /content/1/Seq05VD_f01020_L.png
# 成功處理: /content/1/Seq05VD_f05070_L.png
# 成功處理: /content/1/0016E5_05670_L.png
# 成功處理: /content/1/0016E5_01200_L.png
# 成功處理: /content/1/Seq05VD_f00780_L.png
# 成功處理: /content/1/0001TP_008880_L.png
# 成功處理: /content/1/Seq05VD_f02340_L.png
# 成功處理: /content/1/0016E5_06870_L.png
# 成功處理: /content/1/0001TP_009270_L.png
# 成功處理: /content/1/0001TP_009240_L.png
# 成功處理: /content/1/0016E5_05190_L.png
# 成功處理: /content/1/0016E5_05580_L.png
# 成功處理: /content/1/0001TP_010200_L.png
# 成功處理: /content/1/0016E5_05220_L.png
# 成功處理: /content/1/Seq05VD_f01380_L.png
# 成功處理: /content/1/Seq05VD_f00090_L.png
# 成功處理: /content/1/Seq05VD_f00480_L.png
# 成功處理: /content/1/0016E5_08069_L.png
# 成功處理: /content/1/0016E5_01530_L.png
# 成功處理: /content/1/0016E5_06750_L.png
# 成功處理: /content/1/Seq05VD_f02460_L.png
# 成功處理: /content/1/0016E5_07830_L.png
# 成功處理: /content/1/0016E5_07170_L.png
# 成功處理: /content/1/0016E5_00510_L.png
# 成功處理: /content/1/0001TP_006900_L.png
# 成功處理: /content/1/Seq05VD_f02520_L.png
# 成功處理: /content/1/Seq05VD_f00900_L.png
# 成功處理: /content/1/0016E5_04350_L.png
# 成功處理: /content/1/0006R0_f01770_L.png
# 成功處理: /content/1/Seq05VD_f03660_L.png
# 成功處理: /content/1/0016E5_01680_L.png
# 成功處理: /content/1/Seq05VD_f03270_L.png
# 成功處理: /content/1/Seq05VD_f01050_L.png
# 成功處理: /content/1/0016E5_08047_L.png
# 成功處理: /content/1/0006R0_f01740_L.png
# 成功處理: /content/1/0016E5_08035_L.png
# 成功處理: /content/1/0001TP_006720_L.png
# 成功處理: /content/1/Seq05VD_f01440_L.png
# 成功處理: /content/1/0016E5_07440_L.png
# 成功處理: /content/1/0016E5_01410_L.png
# 成功處理: /content/1/0016E5_00660_L.png
# 成功處理: /content/1/0016E5_02250_L.png
# 成功處理: /content/1/0016E5_08340_L.png
# 成功處理: /content/1/0006R0_f01020_L.png
# 成功處理: /content/1/0016E5_08061_L.png
# 成功處理: /content/1/0016E5_00930_L.png
# 成功處理: /content/1/0001TP_006870_L.png
# 成功處理: /content/1/0016E5_01710_L.png
# 成功處理: /content/1/0001TP_009660_L.png
# 成功處理: /content/1/Seq05VD_f04710_L.png
# 成功處理: /content/1/0006R0_f01590_L.png
# 成功處理: /content/1/0006R0_f03330_L.png
# 成功處理: /content/1/Seq05VD_f02430_L.png
# 成功處理: /content/1/0016E5_08065_L.png
# 成功處理: /content/1/0016E5_07993_L.png
# 成功處理: /content/1/0001TP_007290_L.png
# 成功處理: /content/1/0016E5_06660_L.png
# 成功處理: /content/1/0001TP_008760_L.png
# 成功處理: /content/1/0001TP_007590_L.png
# 成功處理: /content/1/0006R0_f03360_L.png
# 成功處理: /content/1/0001TP_009810_L.png
# 成功處理: /content/1/0001TP_008040_L.png
# 成功處理: /content/1/0006R0_f01620_L.png
# 成功處理: /content/1/0001TP_008220_L.png
# 成功處理: /content/1/0016E5_04710_L.png
# 成功處理: /content/1/0016E5_07973_L.png
# 成功處理: /content/1/Seq05VD_f02160_L.png
# 成功處理: /content/1/0016E5_07981_L.png
# 成功處理: /content/1/0006R0_f03600_L.png
# 成功處理: /content/1/0016E5_07590_L.png
# 成功處理: /content/1/0001TP_008430_L.png
# 成功處理: /content/1/0006R0_f02100_L.png
# 成功處理: /content/1/0016E5_08103_L.png
# 成功處理: /content/1/0016E5_01260_L.png
# 成功處理: /content/1/0001TP_009840_L.png
# 成功處理: /content/1/0016E5_01080_L.png
# 成功處理: /content/1/0006R0_f00960_L.png
# 成功處理: /content/1/0001TP_007200_L.png
# 成功處理: /content/1/0016E5_01170_L.png
# 成功處理: /content/1/0016E5_07975_L.png
# 成功處理: /content/1/0016E5_07650_L.png
# 成功處理: /content/1/0006R0_f01890_L.png
# 成功處理: /content/1/0016E5_04920_L.png
# 成功處理: /content/1/Seq05VD_f01770_L.png
# 成功處理: /content/1/0016E5_08097_L.png
# 成功處理: /content/1/0006R0_f02010_L.png
# 成功處理: /content/1/Seq05VD_f00720_L.png
# 成功處理: /content/1/0001TP_010380_L.png
# 成功處理: /content/1/0001TP_006930_L.png
# 成功處理: /content/1/Seq05VD_f05100_L.png
# 成功處理: /content/1/0006R0_f02490_L.png
# 成功處理: /content/1/0016E5_02070_L.png
# 成功處理: /content/1/0016E5_06960_L.png
# 成功處理: /content/1/0016E5_07020_L.png
# 成功處理: /content/1/0016E5_08137_L.png
# 成功處理: /content/1/0016E5_00630_L.png
# 成功處理: /content/1/0016E5_05700_L.png
# 成功處理: /content/1/Seq05VD_f03420_L.png
# 成功處理: /content/1/0001TP_009720_L.png
# 成功處理: /content/1/0006R0_f01530_L.png
# 成功處理: /content/1/0001TP_006960_L.png
# 成功處理: /content/1/0006R0_f02400_L.png
# 成功處理: /content/1/0001TP_008670_L.png
# 成功處理: /content/1/0016E5_01770_L.png
# 成功處理: /content/1/0016E5_08099_L.png
# 成功處理: /content/1/0016E5_07979_L.png
# 成功處理: /content/1/Seq05VD_f01260_L.png
# 成功處理: /content/1/Seq05VD_f04410_L.png
# 成功處理: /content/1/0016E5_06540_L.png
# 成功處理: /content/1/0006R0_f02370_L.png
# 成功處理: /content/1/Seq05VD_f04440_L.png
# 成功處理: /content/1/0001TP_008790_L.png
# 成功處理: /content/1/0016E5_08370_L.png
# 成功處理: /content/1/0016E5_01140_L.png
# 成功處理: /content/1/0006R0_f03150_L.png
# 成功處理: /content/1/0016E5_04410_L.png
# 成功處理: /content/1/0016E5_02340_L.png
# 成功處理: /content/1/0001TP_009540_L.png
# 成功處理: /content/1/0001TP_010140_L.png
# 成功處理: /content/1/0006R0_f02130_L.png
# 成功處理: /content/1/0001TP_008820_L.png
# 成功處理: /content/1/0016E5_08190_L.png
# 成功處理: /content/1/Seq05VD_f01170_L.png
# 成功處理: /content/1/0016E5_08091_L.png
# 成功處理: /content/1/0016E5_08057_L.png
# 成功處理: /content/1/Seq05VD_f01800_L.png
# 成功處理: /content/1/0001TP_009150_L.png
# 成功處理: /content/1/Seq05VD_f04680_L.png
# 成功處理: /content/1/0006R0_f03000_L.png
# 成功處理: /content/1/0001TP_008580_L.png
# 成功處理: /content/1/0016E5_05010_L.png
# 成功處理: /content/1/0006R0_f03120_L.png
# 成功處理: /content/1/0016E5_07110_L.png
# 成功處理: /content/1/Seq05VD_f01650_L.png
# 成功處理: /content/1/0016E5_05550_L.png
# 成功處理: /content/1/Seq05VD_f02010_L.png
# 成功處理: /content/1/Seq05VD_f03090_L.png
# 成功處理: /content/1/0016E5_08037_L.png
# 成功處理: /content/1/0016E5_05610_L.png
# 成功處理: /content/1/Seq05VD_f01530_L.png
# 成功處理: /content/1/Seq05VD_f01290_L.png
# 成功處理: /content/1/0001TP_007530_L.png
# 成功處理: /content/1/0016E5_06390_L.png
# 成功處理: /content/1/0001TP_008850_L.png
# 成功處理: /content/1/0016E5_07260_L.png
# 成功處理: /content/1/0016E5_07969_L.png
# 成功處理: /content/1/0006R0_f02820_L.png
# 成功處理: /content/1/0001TP_007140_L.png
# 成功處理: /content/1/0006R0_f02520_L.png
# 成功處理: /content/1/0006R0_f01650_L.png
# 成功處理: /content/1/0001TP_007620_L.png
# 成功處理: /content/1/0001TP_008160_L.png
# 成功處理: /content/1/0016E5_06150_L.png
# 成功處理: /content/1/0016E5_06990_L.png
# 成功處理: /content/1/Seq05VD_f04740_L.png
# 成功處理: /content/1/0006R0_f02700_L.png
# 成功處理: /content/1/Seq05VD_f00960_L.png
# 成功處理: /content/1/0006R0_f02880_L.png
# 成功處理: /content/1/Seq05VD_f04140_L.png
# 成功處理: /content/1/0006R0_f03750_L.png
# 成功處理: /content/1/0016E5_08083_L.png
# 成功處理: /content/1/Seq05VD_f00510_L.png
# 成功處理: /content/1/0001TP_006810_L.png
# 成功處理: /content/1/0001TP_007260_L.png
# 成功處理: /content/1/Seq05VD_f04230_L.png
# 成功處理: /content/1/0016E5_08079_L.png
# 成功處理: /content/1/0016E5_08125_L.png
# 成功處理: /content/1/0001TP_008280_L.png
# 成功處理: /content/1/Seq05VD_f03210_L.png
# 成功處理: /content/1/0006R0_f02160_L.png
# 成功處理: /content/1/Seq05VD_f01560_L.png
# 成功處理: /content/1/Seq05VD_f02130_L.png
# 成功處理: /content/1/0001TP_009030_L.png
# 成功處理: /content/1/0001TP_008370_L.png
# 成功處理: /content/1/Seq05VD_f00540_L.png
# 成功處理: /content/1/0016E5_08019_L.png
# 成功處理: /content/1/Seq05VD_f02910_L.png
# 成功處理: /content/1/0006R0_f02280_L.png
# 成功處理: /content/1/0001TP_009870_L.png
# 成功處理: /content/1/0016E5_01350_L.png
# 成功處理: /content/1/0001TP_009750_L.png
# 成功處理: /content/1/0006R0_f03090_L.png
# 成功處理: /content/1/0016E5_05280_L.png
# 成功處理: /content/1/0016E5_05880_L.png
# 成功處理: /content/1/0001TP_009330_L.png
# 成功處理: /content/1/0016E5_04800_L.png
# 成功處理: /content/1/Seq05VD_f02730_L.png
# 成功處理: /content/1/Seq05VD_f01080_L.png
# 成功處理: /content/1/0001TP_010170_L.png
# 成功處理: /content/1/Seq05VD_f04200_L.png
# 成功處理: /content/1/0001TP_009480_L.png
# 成功處理: /content/1/0016E5_07320_L.png
# 成功處理: /content/1/0016E5_08023_L.png
# 成功處理: /content/1/Seq05VD_f04890_L.png
# 成功處理: /content/1/Seq05VD_f02850_L.png
# 成功處理: /content/1/0016E5_06180_L.png
# 成功處理: /content/1/0001TP_010080_L.png
# 成功處理: /content/1/0016E5_05340_L.png
# 成功處理: /content/1/0001TP_008310_L.png
# 成功處理: /content/1/Seq05VD_f02490_L.png
# 成功處理: /content/1/0016E5_08640_L.png
# 成功處理: /content/1/Seq05VD_f01320_L.png
# 成功處理: /content/1/0016E5_07740_L.png
# 成功處理: /content/1/0006R0_f01560_L.png
# 成功處理: /content/1/0016E5_06270_L.png
# 成功處理: /content/1/Seq05VD_f04770_L.png
# 成功處理: /content/1/0016E5_02370_L.png
# 成功處理: /content/1/0016E5_08119_L.png
# 成功處理: /content/1/0001TP_007050_L.png
# 成功處理: /content/1/Seq05VD_f05040_L.png
# 成功處理: /content/1/Seq05VD_f00000_L.png
# 成功處理: /content/1/0016E5_01590_L.png
# 成功處理: /content/1/0016E5_04770_L.png
# 成功處理: /content/1/0016E5_04440_L.png
# 成功處理: /content/1/0006R0_f00930_L.png
# 成功處理: /content/1/Seq05VD_f03630_L.png
# 成功處理: /content/1/Seq05VD_f03930_L.png
# 成功處理: /content/1/0006R0_f01380_L.png
# 成功處理: /content/1/0016E5_08143_L.png
# 成功處理: /content/1/0006R0_f03240_L.png
# 成功處理: /content/1/0016E5_08049_L.png
# 成功處理: /content/1/0006R0_f02040_L.png
# 成功處理: /content/1/0016E5_06240_L.png
# 成功處理: /content/1/Seq05VD_f00390_L.png
# 成功處理: /content/1/Seq05VD_f04650_L.png
# 成功處理: /content/1/0016E5_08127_L.png
# 成功處理: /content/1/Seq05VD_f04590_L.png
# 成功處理: /content/1/Seq05VD_f00270_L.png
# 成功處理: /content/1/0016E5_07959_L.png
# 成功處理: /content/1/0001TP_008130_L.png
# 成功處理: /content/1/Seq05VD_f00180_L.png
# 成功處理: /content/1/0016E5_05970_L.png
# 成功處理: /content/1/0016E5_04740_L.png
# 成功處理: /content/1/0016E5_08145_L.png
# 成功處理: /content/1/Seq05VD_f02580_L.png
# 成功處理: /content/1/Seq05VD_f04020_L.png
# 成功處理: /content/1/0016E5_07965_L.png
# 成功處理: /content/1/Seq05VD_f04830_L.png
# 成功處理: /content/1/0001TP_010350_L.png
# 成功處理: /content/1/Seq05VD_f03330_L.png
# 成功處理: /content/1/0016E5_04590_L.png
# 成功處理: /content/1/Seq05VD_f02070_L.png
# 成功處理: /content/1/0016E5_08149_L.png
# 成功處理: /content/1/Seq05VD_f02970_L.png
# 成功處理: /content/1/0016E5_01860_L.png
# 成功處理: /content/1/0016E5_04980_L.png
# 成功處理: /content/1/0001TP_008550_L.png
# 成功處理: /content/1/0016E5_05070_L.png
# 成功處理: /content/1/Seq05VD_f03450_L.png
# 成功處理: /content/1/Seq05VD_f02790_L.png
# 成功處理: /content/1/0016E5_07770_L.png
# 成功處理: /content/1/0001TP_008460_L.png
# 成功處理: /content/1/Seq05VD_f03150_L.png
# 成功處理: /content/1/0016E5_02100_L.png
# 成功處理: /content/1/0016E5_06900_L.png
# 成功處理: /content/1/0006R0_f01440_L.png
# 成功處理: /content/1/0016E5_01560_L.png
# 成功處理: /content/1/Seq05VD_f01830_L.png
# 成功處理: /content/1/0016E5_08067_L.png
# 成功處理: /content/1/0016E5_06000_L.png
# 成功處理: /content/1/Seq05VD_f02700_L.png
# 成功處理: /content/1/0006R0_f01920_L.png
# 成功處理: /content/1/0006R0_f03540_L.png
# 成功處理: /content/1/Seq05VD_f04800_L.png
# 成功處理: /content/1/0006R0_f03690_L.png
# 成功處理: /content/1/0001TP_009000_L.png
# 成功處理: /content/1/0016E5_04650_L.png
# 成功處理: /content/1/Seq05VD_f02670_L.png
# 成功處理: /content/1/0016E5_01020_L.png
# 成功處理: /content/1/Seq05VD_f03360_L.png
# 成功處理: /content/1/0001TP_009360_L.png
# 成功處理: /content/1/Seq05VD_f04320_L.png
# 成功處理: /content/1/0016E5_07410_L.png
# 成功處理: /content/1/0016E5_08075_L.png
# 成功處理: /content/1/0016E5_06090_L.png
# 成功處理: /content/1/Seq05VD_f02640_L.png
# 成功處理: /content/1/0016E5_08013_L.png
# 成功處理: /content/1/0001TP_007560_L.png
# 成功處理: /content/1/Seq05VD_f02280_L.png
# 成功處理: /content/1/0016E5_01440_L.png
# 成功處理: /content/1/0006R0_f00990_L.png
# 成功處理: /content/1/0016E5_01620_L.png
# 成功處理: /content/1/0006R0_f01110_L.png
# 成功處理: /content/1/Seq05VD_f04980_L.png
# 成功處理: /content/1/0001TP_009960_L.png
# 成功處理: /content/1/0001TP_009900_L.png
# 成功處理: /content/1/0016E5_00750_L.png
# 成功處理: /content/1/0016E5_08155_L.png
# 成功處理: /content/1/Seq05VD_f04860_L.png
# 成功處理: /content/1/0001TP_007920_L.png
# 成功處理: /content/1/0006R0_f03390_L.png
# 成功處理: /content/1/Seq05VD_f03060_L.png
# 成功處理: /content/1/0001TP_009780_L.png
# 成功處理: /content/1/0001TP_007230_L.png
# 成功處理: /content/1/0016E5_07985_L.png
# 成功處理: /content/1/0016E5_00690_L.png
# 成功處理: /content/1/0006R0_f01680_L.png
# 成功處理: /content/1/0006R0_f02610_L.png
# 成功處理: /content/1/0016E5_07860_L.png
# 成功處理: /content/1/0016E5_01800_L.png
# 成功處理: /content/1/0016E5_05250_L.png
# 成功處理: /content/1/0016E5_05520_L.png
# 成功處理: /content/1/0016E5_04470_L.png
# 成功處理: /content/1/0001TP_009990_L.png
# 成功處理: /content/1/0016E5_07140_L.png
# 成功處理: /content/1/Seq05VD_f00660_L.png
# 成功處理: /content/1/Seq05VD_f01740_L.png
# 成功處理: /content/1/0006R0_f03720_L.png
# 成功處理: /content/1/Seq05VD_f02940_L.png
# 成功處理: /content/1/0016E5_05040_L.png
# 成功處理: /content/1/Seq05VD_f01920_L.png
# 成功處理: /content/1/0016E5_08031_L.png
# 成功處理: /content/1/Seq05VD_f01710_L.png
# 成功處理: /content/1/Seq05VD_f03900_L.png
# 成功處理: /content/1/Seq05VD_f02820_L.png
# 成功處理: /content/1/Seq05VD_f02220_L.png
# 成功處理: /content/1/0006R0_f02250_L.png
# 成功處理: /content/1/0006R0_f02430_L.png
# 成功處理: /content/1/0016E5_08085_L.png
# 成功處理: /content/1/0016E5_00570_L.png
# 成功處理: /content/1/0006R0_f03450_L.png
# 成功處理: /content/1/0016E5_07560_L.png
# 成功處理: /content/1/0006R0_f03810_L.png
# 成功處理: /content/1/0001TP_007020_L.png
# 成功處理: /content/1/0016E5_07200_L.png
# 成功處理: /content/1/0006R0_f01800_L.png
# 成功處理: /content/1/0016E5_07961_L.png
# 成功處理: /content/1/Seq05VD_f00690_L.png
# 成功處理: /content/1/0001TP_007500_L.png
# 成功處理: /content/1/Seq05VD_f02370_L.png
# 成功處理: /content/1/Seq05VD_f00150_L.png
# 成功處理: /content/1/Seq05VD_f01500_L.png
# 成功處理: /content/1/0016E5_08087_L.png
# 成功處理: /content/1/Seq05VD_f03000_L.png
# 成功處理: /content/1/0001TP_007740_L.png
# 成功處理: /content/1/Seq05VD_f04620_L.png
# 成功處理: /content/1/0016E5_08109_L.png
# 成功處理: /content/1/Seq05VD_f02250_L.png
# 成功處理: /content/1/0016E5_04890_L.png
# 成功處理: /content/1/0006R0_f03570_L.png
# 處理完成！成功: 701 個文件，失敗: 0 個文件

# %%
#下載
import shutil

# 定義資料夾路徑和壓縮後的檔案名
folder_path = "/content/output1"
output_filename = "/content/output.zip"

# 壓縮資料夾
shutil.make_archive(output_filename.replace(".zip", ""), 'zip', folder_path)

print(f"{folder_path} 已壓縮為 {output_filename}")

from google.colab import files

# 下載壓縮檔案
files.download(output_filename)
# Out:
# /content/output1 已壓縮為 /content/output.zip
